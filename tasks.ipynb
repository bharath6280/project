# %%
#create apython script with both single line comment and multiline comment
num1=10 #10 value is assign to num1
num2=20 #20 value is assign to num2
print(num1,num2) #print the both num1,num2 values

""" initialy 10 value is assigned to variable num1
    next number 20 is assigned to variable num2
    then 
    print the both num1,num2 values usting print statement


"""
